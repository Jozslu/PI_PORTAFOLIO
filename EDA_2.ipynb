# %% [markdown]
# # ANÁLISIS EXPLORATORIO Y VISUALIZACIÓN DE DATOS.

# %% [markdown]
# ### Importando las librerías a utilizar.

# %%
import pandas as pd 
import numpy as np
import missingno as msno 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargando el dataset

# %%
df_data = pd.read_csv("data_general.csv", index_col= False, sep=",", header= 0)

# %% [markdown]
# ## Analizamos el nuevo Dataframe

# %%
# Mostrando los primeros datos.
df_data.head()
# Out:
#     type                 title        director  \
# 0  movie   the grand seduction    don mckellar
# 1  movie  take care good night    girish joshi
# 2  movie  secrets of deception     josh webber
# 3  movie    pink: staying true  sonia anderson
# 4  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#      date_added  release_year rating                listed_in  \
# 0  2021- 03- 30          2014      g            comedy, drama
# 1  2021- 03- 30          2018    13+     drama, international
# 2  2021- 03- 30          2017      g  action, drama, suspense
# 3  2021- 03- 30          2014      g              documentary
# 4  2021- 03- 30          1989      g           drama, fantasy
#
#                                          description   id plataforma  \
# 0  a small fishing village must procure a local d...  as1     amazon
# 1  a metro family decides to fight a cyber crimin...  as2     amazon
# 2  after a man discovers his wife is cheating on ...  as3     amazon
# 3  pink breaks the mold once again, bringing her ...  as4     amazon
# 4  teenage matt banting wants to work with a famo...  as5     amazon
#
#    duration_int duration_type  score
# 0         113.0           min    3.5
# 1         110.0           min    3.5
# 2          74.0           min    3.5
# 3          69.0           min    3.5
# 4          45.0           min    3.5

# %%
# Analizamos la información de sus datos.
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22998 entries, 0 to 22997
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           22998 non-null  object
#  1   title          22998 non-null  object
#  2   director       14739 non-null  object
#  3   cast           17677 non-null  object
#  4   country        11499 non-null  object
#  5   date_added     13444 non-null  object
#  6   release_year   22998 non-null  int64
#  7   rating         22998 non-null  object
#  8   listed_in      22998 non-null  object
#  9   description    22994 non-null  object
#  10  id             22998 non-null  object
#  11  plataforma     22998 non-null  object
#  12  duration_int   22516 non-null  float64
#  13  duration_type  22516 non-null  object
#  14  score          22998 non-null  float64
# dtypes: float64(2), int64(1), object(12)
# memory usage: 2.6+ MB

# %%
# Calculamos en número de celdas vacías en cada colummna.
datos_faltantes = df_data.isnull().sum().to_frame()
datos_faltantes = datos_faltantes.rename(columns= {0: " Celdas Vacías"})
datos_faltantes
# Out:
#                 Celdas Vacías
# type                        0
# title                       0
# director                 8259
# cast                     5321
# country                 11499
# date_added               9554
# release_year                0
# rating                      0
# listed_in                   0
# description                 4
# id                          0
# plataforma                  0
# duration_int              482
# duration_type             482
# score                       0

# %%
# Visualizamos el "gráfico matriz" y observamos algún posible patrón entre los datos faltantes.
msno.matrix(df_data, figsize=(10,5), fontsize=11)
# Out:
# <AxesSubplot: >

# %%
# Visualizamos la proporción de datos faltantes por cada variable (columnas).
df_data.isnull().melt().pipe(lambda df:(sns.displot(data= df, y= "variable", hue= "value", multiple= "fill", aspect= 2)))

# %%
# Visualizamos los valores nulos por cada observación (filas).
df_data.isnull().transpose().pipe(lambda df: (sns.heatmap(data= df)))
# Out:
# <AxesSubplot: >

# %%
# Visualizamos la correlación de nulidad entre las variables.
msno.heatmap(df_data,  figsize=(10,5), fontsize=11)
# Out:
# <AxesSubplot: >

# %%
# Mostrando la forma del Dataframe Amazon, cantidad de filas y columnas.
print(df_data.shape)
